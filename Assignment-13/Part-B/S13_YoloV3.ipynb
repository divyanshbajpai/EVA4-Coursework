# %% [markdown]
# <a href="https://colab.research.google.com/github/divyanshbajpai/EVA4-Coursework/blob/master/Assignment-13/Part-B/S13_YoloV3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/divyanshbajpai/YoloV3.git
# Out:
# Cloning into 'YoloV3'...
# remote: Enumerating objects: 906, done.
# remote: Counting objects: 100% (906/906), done.
# remote: Compressing objects: 100% (880/880), done.
# remote: Total 1062 (delta 6), reused 904 (delta 6), pack-reused 156
# Receiving objects: 100% (1062/1062), 16.54 MiB | 3.23 MiB/s, done.
# Resolving deltas: 100% (13/13), done.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.4.0 _CudaDeviceProperties(name='Tesla P4', major=6, minor=1, total_memory=7611MB, multi_processor_count=20)

# %%
ls
# Out:
# gdrive/  sample_data/  YoloV3/

# %%
cd YoloV3/
# Out:
# /content/YoloV3

# %%
# !ls
# Out:
#  annotation_tool   output	  results.txt	     train.py
#  cfg		   __pycache__	  test_batch0.png   'ubdivisions=1'
#  data		   README.md	  test.py	     utils
#  detect.py	   results.json   ting		     vim.exe.stackdump
#  models.py	   results.png	  train_batch0.png   weights

# %%
# !python train.py --data data/smalcoco/smalcoco.data --batch 3 --cache --epochs 3 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=3, bucket='', cache_images=True, cfg='cfg/yolov3-spp.cfg', data='data/smalcoco/smalcoco.data', device='', epochs=3, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P4', total_memory=7611MB)
#
# 2020-04-26 13:22:45.969226: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.29987e+07 parameters, 6.29987e+07 gradients
# Caching labels (20 found, 0 missing, 0 empty, 0 duplicate, for 20 images): 100% 20/20 [00:00<00:00, 6184.46it/s]
# Caching images (0.0GB): 100% 20/20 [00:00<00:00, 116.55it/s]
# ...

# %%
# !python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 3 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=3, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P4', total_memory=7611MB)
#
# 2020-04-26 13:23:33.997790: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# Caching labels (432 found, 0 missing, 24 empty, 0 duplicate, for 456 images): 100% 456/456 [00:00<00:00, 10884.93it/s]
# Caching images (0.3GB): 100% 456/456 [00:00<00:00, 806.24it/s]
# ...

# %%
# !python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 150 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=150, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P4', total_memory=7611MB)
#
# 2020-04-26 13:29:05.201162: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# Caching labels (432 found, 0 missing, 24 empty, 0 duplicate, for 456 images): 100% 456/456 [00:00<00:00, 11191.88it/s]
# Caching images (0.3GB): 100% 456/456 [00:00<00:00, 835.55it/s]
# ...

# %%
# !python detect.py --conf-thres 0.1 --output out_out
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='out_out', save_txt=False, source='data/customdata/images', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P4', total_memory=7611MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# image 1/456 data/customdata/images/a1.jpg: 512x512 1 kungfu-pandas, Done. (0.038s)
# image 2/456 data/customdata/images/a10.jpg: 256x512 1 kungfu-pandas, Done. (0.027s)
# image 3/456 data/customdata/images/a100.jpg: 512x512 1 kungfu-pandas, Done. (0.039s)
# image 4/456 data/customdata/images/a101.jpg: 384x512 1 kungfu-pandas, Done. (0.033s)
# image 5/456 data/customdata/images/a102.jpg: 320x512 1 kungfu-pandas, Done. (0.030s)
# image 6/456 data/customdata/images/a103.jpg: 512x384 1 kungfu-pandas, Done. (0.033s)
# ...

# %%
cd ../gdrive/My\ Drive/Assignment-13
# Out:
# /content/gdrive/My Drive/Assignment-13

# %%
Image(filename='out_out/a99.jpg', width=600)

# %%
Image(filename='out_out/a77.jpg', width=600)

# %%
Image(filename='out_out/a1.jpg', width=600)

# %%
Image(filename='out_out/a20.jpg', width=600)
